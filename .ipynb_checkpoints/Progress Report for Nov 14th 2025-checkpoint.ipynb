# %% [markdown]
# # Progress Report (14th November 2025)

# %% [markdown]
# ## Inroduction

# %% [markdown]
# Analysing crowdfunding campaign data to pick up trends as to what affects campaign success. The website used for data is an Indian Crowdfunding website (milaap: https://milaap.org/)<br>

# %% [markdown]
# ## Any changes since the proposal

# %% [markdown]
# No change

# %% [markdown]
# ## Data

# %% [markdown]
# - Data was webscraped from the Milaap Website
# - I will go into the webscraping in detail

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# We have somewhat gone into the analysis step blind. As in not trying to predict or any specific goal in mind, just as suggested in class.
